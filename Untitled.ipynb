# %%
from SimData import SimData

SimData.initialize(1000,2, 10000)
# Out:
# Reading Data..
# deleted tick data for initialization. (use 10000 data for simualtion.
# Calculating Index Data..
# Completed initialization of SimData
# num_data=10000, : from_dt=2019-05-21 14:20:34, - to_dt=2019-05-21 21:00:35

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(SimData.ticks.sma_kairi[500][1000:1500],label='incli')

# %%
plt.plot(SimData.ticks.sma[500][1000:1500],label='sma')

# %%
SimData.ticks.sma_incli[2][:10]
# Out:
# array([    nan,     nan,    0.5 ,    0.25,   -0.25,   -0.5 ,   -0.25,
#         124.75,  124.75, -124.75])

# %%
li = [10,11,12,13,10,9]

# %%
import numpy as np
np.gradient(li)
# Out:
# array([ 1.,  1.,  1., -1., -2., -1.])
